# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def detectCycle(self, head: ListNode) -> ListNode:
        slow = fast = head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
            if slow == fast:
                node = head
                while node != slow:
                    node = node.next
                    slow = slow.next
                return node
        return None

# %%
class Node:
    def __init__(self,data=None,next=None):
        self.data=data
        self.next=next
class LinkedList:
    def __init__(self):
        self.head=None
        
    def insert_beg(self,data):
        node = Node(data, self.head)
        self.head = node
    def print(self):
        if self.head is None:
            print('Empty')
            return
        itr=self.head
        listr=''
        while itr:
            listr+=str(itr.data)+'-->'
            itr=itr.next
        print(listr)
    def getlen(self):
        itr=self.head
        count=0
        while itr:
            count+=1
            itr=itr.next
        return count
    def search(self,data):
        itr=self.head
        true=[]
        while itr:
            if itr.data==data:
                true.append(True)
            else:
                true.append(False)
            itr=itr.next
        return True in true
    def insert_end(self,data):
        itr=self.head
        node = Node(data, self.head)
        while itr.next:
            itr=itr.next
        itr.next=node
        node.next=None
    def insert_mid(self,data1,data2):
        itr=self.head
        node=Node(data2,self.head)#data2 for inserting in the middle
        while itr:
            if itr.data==data1:
                node.next=itr.next
                itr.next=node
                #print(itr.data)
            itr=itr.next
    def remove_last(self):
        itr=self.head
        if itr:
            while itr.next.next:
                itr=itr.next
            rm=itr.next
            itr.next=None
        elif(itr==None):
            print('can.t do operation  ')
    def hashcycle(self):
        

if __name__=='__main__':
                
    ll=LinkedList()
    print('Linked List')
    for i in range(5):
        ll.insert_beg(i)

    print(ll.search(5))
    print(ll.getlen())
    ll.print()
    ll.insert_end(100)
    ll.print()
    ll.insert_mid(3,501)
    ll.print()
    ll.remove_last()
    ll.print()
